# %% [markdown]
# <a href="https://www.kaggle.com/code/akashgoe/case-study-imdb?scriptVersionId=131702044" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Setup Complete

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %%
step_1.check()
# Out:
# Correct:

# %%
my_filepath = "/kaggle/input/akashimdb/IMDB Top 250 Movies.csv"
step_2.check()
# Out:
# Correct:

# %%
my_data = pd.read_csv(my_filepath)
step_3.check()
# Out:
# Correct:

# %%
my_data.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
sns.lineplot(data=my_data)
step_4.check()
# Out:
# Correct:

# %%
sns.barplot(data=my_data)
step_4.check()
# Out:
# Correct:

# %%
sns.scatterplot(data=my_data)
step_4.check()
# Out:
# Correct:

# %%
sns.scatterplot(x=my_data['rank'], y=my_data['rating'], hue=my_data['year'])
# Out:
# <AxesSubplot: xlabel='rank', ylabel='rating'>

# %%
my_filepath = "/kaggle/input/akashimdb/IMDB Top 250 Movies.csv"
my_data = pd.read_csv(my_filepath)
my_data.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
sns.histplot(my_data['rating'])
# Out:
# <AxesSubplot: xlabel='rating', ylabel='Count'>

# %%
sns.kdeplot(data=my_data['rating'], shade=True)
# Out:
# /tmp/ipykernel_20/1566781237.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=my_data['rating'], shade=True)
# <AxesSubplot: xlabel='rating', ylabel='Density'>
